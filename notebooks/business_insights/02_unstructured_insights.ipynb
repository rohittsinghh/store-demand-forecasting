# %%
import sys
import os

sys.path.append(os.path.abspath(os.path.join("..", "..")))

from src.text_analysis import extract_keywords

keywords = extract_keywords("../../data/unstructured/store_notes.txt")
keywords
